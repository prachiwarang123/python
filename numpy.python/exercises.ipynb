# %%
import numpy as np

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],

    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],

    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]

])

# %%
b = np.sum(s,axis = 1)
for i in b:
    if i != 45:
        print("suduko is not valid")
        break
else:
    print("for rows it is valid")
# Out:
# for rows it is valid

# %%
c = np.sum(s,axis = 1)
for i in b:
    if i != 45:
        print("suduko is not valid")
        break
else:
    print("for columns it is valid")
# Out:
# for columns it is valid

# %%
s[0:3,0:3]
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
s[0:3,3:6]
# Out:
# array([[6, 7, 8],
#        [1, 9, 5],
#        [3, 4, 2]])

# %%
s[0:3,6:9]
# Out:
# array([[9, 1, 2],
#        [3, 4, 8],
#        [5, 6, 7]])

# %%
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %%
for i in range(0,9,3):
    for j in range(0,9,3):
       n = s[i:i+3,j:j+3]
    print(n.sum())
# Out:
# 45
# 45
# 45

# %%
 import numpy as np

#columns: [age, maths marks, science marks]
data =  np.array([
    [18, 85, 78], #student 1
    [19, 92, 88],
    [17, 76, 95],
    [18, 65, 78],
    [20, 90, 85]
])

# %%
#shape of matrix
data.shape
# Out:
# (5, 3)

# %%
#avarage age
np.mean(data[:,0])
# Out:
# 18.4

# %%
#extract math marks
data[:,1]
# Out:
# array([85, 92, 76, 65, 90])

# %%
#highest science marks
np.max(data[:,2])
# Out:
# 95

# %%
#scored more than 90 in maths
data[data[:,1]>90]
# Out:
# array([[19, 92, 88]])

# %%
#increase maths maerks by 5
data[:,1] +=  5
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 78],
#        [20, 95, 85]])

# %%
# students younger than 90

#data[:,0]<19
len(data[data[:,0]<19])
# Out:
# 3

# %%
#average marks in each subject column vise
np.mean(data[:,1:], axis = 0)
# Out:
# array([86.6, 84.8])

# %%
#data of studemnts who scored at least 80 in both subjects

data[(data[:,1] >= 80) & (data[:,2] >= 80 )]
# Out:
# array([[19, 97, 88],
#        [17, 81, 95],
#        [20, 95, 85]])

# %%
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 78],
#        [20, 95, 85]])

# %%
#replace all science marks < 75 with 0
data[:,2][data[:,2] < 75] = 0
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 78],
#        [20, 95, 85]])
