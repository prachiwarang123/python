# %%
import numpy as np
import pandas as pd

# %%
#creating DataFrames

# %%
data = {
    'Name' : ['John', 'Prachi', 'Aku', 'Riya'],
    'Age' : [28, 21, 25, 17],
    'City' : ['New York', 'paris', 'Berlin', 'London'],
    'Salary' : [65000, 90000, 70000, 60000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1  Prachi   21     paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
data_list = [
    ['Johhn', 28, 'New York', 65000],
    ['Prachi', 21, 'Paris', 90000],
    ['Aku', 25, 'Berlin', 70000],
    ['Riya', 17, 'London', 60000]
]

df2 = pd.DataFrame(data_list, columns=['Name', 'Age', 'City', 'Salary'])
print(df2)
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
#selection and indexing of columns

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
df2['Name']
# Out:
# 0     Johhn
# 1    Prachi
# 2       Aku
# 3      Riya
# Name: Name, dtype: object

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[['Name', 'City']]
# Out:
#      Name      City
# 0   Johhn  New York
# 1  Prachi     Paris
# 2     Aku    Berlin
# 3    Riya    London

# %%
#Creating a new column

# %%
df2["Designation"] = ["Doctor", "Engineer", "Data Analytics", "CA"]

# %%
df2
# Out:
#      Name  Age      City  Salary     Designation
# 0   Johhn   28  New York   65000          Doctor
# 1  Prachi   21     Paris   90000        Engineer
# 2     Aku   25    Berlin   70000  Data Analytics
# 3    Riya   17    London   60000              CA

# %%
#Removing column

# %%
df2.drop('Designation', axis = 1)
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
df2
# Out:
#      Name  Age      City  Salary     Designation
# 0   Johhn   28  New York   65000          Doctor
# 1  Prachi   21     Paris   90000        Engineer
# 2     Aku   25    Berlin   70000  Data Analytics
# 3    Riya   17    London   60000              CA

# %%
df2.drop('Designation', axis = 1, inplace = True)

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
df2.drop(0, axis = 0)
# Out:
#      Name  Age    City  Salary
# 1  Prachi   21   Paris   90000
# 2     Aku   25  Berlin   70000
# 3    Riya   17  London   60000

# %%
#Selecting row

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
df2.loc[[0,1]]
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000

# %%
df.iloc[1]
# Out:
# Name      Prachi
# Age           21
# City       paris
# Salary     90000
# Name: 1, dtype: object

# %%
#selecting subsets of rows and columns

# %%
df2.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   90000

# %%
df2.loc[[2,3]][['Name', 'Age']]
# Out:
#    Name  Age
# 2   Aku   25
# 3  Riya   17

# %%
#Conditional Selection

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000
# 3    Riya   17    London   60000

# %%
#people whose age is above 20

# %%
df2[df2['Age'] > 20]
# Out:
#      Name  Age      City  Salary
# 0   Johhn   28  New York   65000
# 1  Prachi   21     Paris   90000
# 2     Aku   25    Berlin   70000

# %%
#people whose age is above 20 n are from paris

# %%
df2[(df2['Age'] > 20) & (df2['City'] == 'Paris')]
# Out:
#      Name  Age   City  Salary
# 1  Prachi   21  Paris   90000
