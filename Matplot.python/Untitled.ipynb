# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 12, 100)
y = np.sin(x)

fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axis1.plot(x, y)

# Save as JPEG
fig.savefig("my_plot.jpeg", format='jpeg', dpi=300)

plt.show()
